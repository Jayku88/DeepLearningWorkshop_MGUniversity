# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/Jayku88/DeepLearningWorkshop_MGUniversity/blob/main/Student_Notebook_2.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
#  **We will build a convolutional neural network model to solve a basic image classification problem. We will accomplish this with the help of following tasks in the project:**
# 1.   Understand the problem statement
# 2.   Understand the dataset
# 3.   Encode the labels
# 4.   Understand convolution neural networks
# 5.   Preprocess image examples
# 6.   Create a neural network model
# 7.   Train the model to fit the dataset
# 8.   Evaluate the model

# %% [markdown]
# # Task 1: Introduction
#
# Welcome to Basic Image Classification with TensorFlow.
#
# This graph describes the problem that we are trying to solve visually. We want to create and train a model that takes an image of a hand written digit as input and predicts the class of that digit, that is, it predicts the digit or it predicts the class of the input image.
# ![1_1.png](data:image/png;base64,...)

# %% [markdown]
# ### Import TensorFlow

# %%
import tensorflow as tf

#tf.logging.set_verbosity(tf.logging.ERROR)
print('Using TensorFlow version', tf.__version__)

# %% [markdown]
# # Task 2: The Dataset
# ### Import MNIST

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
from tensorflow.keras.datasets import mnist
(x_train,y_train), (x_test,y_test)=mnist.load_data()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Convert y_train to labels if needed
if len(y_train.shape) > 1 and y_train.shape[1] > 1:
    y_labels = np.argmax(y_train, axis=1)
else:
    y_labels = y_train

# Count samples per class
unique_classes, counts = np.unique(y_labels, return_counts=True)

# Print counts
print("Number of samples per class:")
for cls, count in zip(unique_classes, counts):
    print(f"Class {cls}: {count} samples")

# Create a DataFrame for better plotting
df = pd.DataFrame({'Class': unique_classes, 'Count': counts})

# Plot without future warning
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='Class', y='Count', hue='Class', palette='icefire', legend=False)
plt.xlabel("Class Label")
plt.ylabel("Number of Samples")
plt.title("Number of Samples per Class in X_train")
plt.show()

# %% [markdown]
# ### Shapes of Imported Arrays

# %%
x_train.shape

# %%
x_test.shape

# %%
x_train[0].shape

# %%
y_train[0]

# %% [markdown]
# ### Plot an Image Example

# %%
plt.matshow(x_train[0])

# %% [markdown]
# # Task 4: Convolution Neural Networks

# %% [markdown]
# ## Sample CNN

# %% [markdown]
# ![cnn.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Convolution Operation

# %% [markdown]
# ![convolution.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Activation function (ReLU)

# %% [markdown]
# ![RELU.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Padding

# %% [markdown]
# ![pooling.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Max pooling

# %% [markdown]
# ![maxpool.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Flattening

# %% [markdown]
# ![flattenigng.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ![dataaugmentation.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Task 5: Preprocessing the Examples

# %% [markdown]
# ### Data Normalization

# %%
x_train = x_train / 255
x_test = x_test / 255

# %% [markdown]
# # Task 6: Creating a Model
# ### Creating the Model

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()

# %% [markdown]
# # Task 7: Training the Model
#
# ### Training the Model

# %%
history=model.fit(x_train, y_train, epochs=5)

# %% [markdown]
# ### Evaluating the Model

# %%
model.evaluate(x_test,y_test)

# %%
plt.plot(history.history['loss'], color='b', label="loss")
plt.title("Training Loss")
plt.xlabel("Number of Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# # Task 8: Visualization

# %% [markdown]
# ### Plotting the Results

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
y_pred_probs = model.predict(x_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = y_test


# Create confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot using seaborn
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
